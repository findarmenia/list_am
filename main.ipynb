# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import requests as req
import pandas as pd
import scrapy
import csv
import numpy

# %%
resp = req.get("https://www.list.am/category/23?bid=76&price1=&price2=&crc=-1&_a27=0&_a2_1=0&_a2_2=0&_a1_1=0&_a1_2=0&_a15=0&_a28_1=0&_a28_2=0&_a13=0&_a16=0&_a17=0&_a23=0&_a22=0&n=0")

# %%
soup = BeautifulSoup(resp.content, 'lxml')

# %%
cars_div = soup.find_all("div", { "class" : "gl" })[1]

# %%
car_names = ["car name"]
car_prices = ["car price"]
car_links = ["car url"]
for car_as in cars_div.find_all("a"):
        name = car_as.find("div", {"class" : "l"})         
        for price in car_as.find_all("div", { "class" : "p" }):
            #print("{0}: {1}".format("price", price.text))
            car_prices.append(price.text)       
        #price = car_as.find("div", { "class" : "p" })
        car_links.append("https://list.am"+car_as.get('href'))  
        car_names.append(name.text)

# %%
full_information_array = [car_names, car_prices, car_links]
#print(full_information_array)

# %%
list_for_csv = pd.DataFrame(full_information_array)

# %%
list_for_csv.to_csv('list.csv')

# %%
pd.read_csv('list.csv')
# Out:
#    Unnamed: 0          0                              1  \
# 0           0   car name          Toyota Camry, 2011 թ.
# 1           1  car price                        $12,500
# 2           2    car url  https://list.am/item/10608614
#
#                                2                                3  \
# 0        Toyota Alphard, 2007 թ.  Toyota Camry, 2014 թ. Poxanakum
# 1                         $8,800                          $10,400
# 2  https://list.am/item/12848615    https://list.am/item/13167507
#
#                                                    4  \
# 0  Toyota Land Cruiser Prado, 2011 թ. (4. L MATOR...
# 1                                            $27,000
# 2                      https://list.am/item/12734179
#
#                                                    5  \
# 0  Toyota Land Cruiser Prado, 2011 թ. 4.0 L (FUL)...
# 1                                            $27,000
# 2                      https://list.am/item/12734513
#
#                                  6  \
# 0  Toyota Camry, 2018 թ. POXANAKUM
# 1                          $16,500
# 2    https://list.am/item/12510226
#
#                                                7  \
# 0  Toyota Corolla, Camry 2008-2016 kgnem vtarvac
# 1                                       10,000 ֏
# 2                   https://list.am/item/8361915
#
#                                            8  ...  \
# 0  Toyota Tundra, 2009 թ. 5.7L 4x4 POXANAKUM  ...
# 1                                    $25,999  ...
# 2              https://list.am/item/13099873  ...
#
#                                      87  \
# 0  Toyota Camry SE sev salon Start stop
# 1                                $8,700
# 2         https://list.am/item/13163291
#
#                                                   88  \
# 0  Pntrum em avtomeqena hoxataracqi het poxanakel...
# 1                                                NaN
# 2                      https://list.am/item/12496440
#
#                               89                             90  \
# 0            Toyota alphard 2007               Toyota voxy 2008
# 1                            NaN                            NaN
# 2  https://list.am/item/12564499  https://list.am/item/12404845
#
#                               91                             92  \
# 0                   Toyota ipsum                    Toyota voxy
# 1                            NaN                            NaN
# 2  https://list.am/item/12345394  https://list.am/item/12873447
#
#                               93                             94  \
# 0          Toyota Camry, 2010 թ.                 Toyota alphard
# 1                            NaN                            NaN
# 2  https://list.am/item/12823171  https://list.am/item/13312251
#
#                                 95                                 96
# 0  Toyota Camry, 2014 թ. POXANAKUM  Toyota Corolla, 2011 թ. POXANAKUM
# 1                              NaN                                NaN
# 2    https://list.am/item/13702934      https://list.am/item/13680057
#
# [3 rows x 98 columns]
